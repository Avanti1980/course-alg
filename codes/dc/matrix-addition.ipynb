# %%
import numpy as np


def add(A, B, m, n):
    C = np.empty((m, n))
    for i in range(m):
        for j in range(n):
            C[i, j] = A[i, j] + B[i, j]
    return C


def add_rec(A, B, C, shape):
    m, n = shape
    if m == 1 or n == 1:
        C[:] = A[:] + B[:]
    else:
        mid_m, mid_n = int(m / 2), int(n / 2)

        # 四个子矩阵的索引
        block_11 = slice(None, mid_m), slice(None, mid_n)
        block_12 = slice(None, mid_m), slice(mid_n, None)
        block_21 = slice(mid_m, None), slice(None, mid_n)
        block_22 = slice(mid_m, None), slice(mid_n, None)

        add_rec(A[block_11], B[block_11], C[block_11], A[block_11].shape)
        add_rec(A[block_12], B[block_12], C[block_12], A[block_12].shape)
        add_rec(A[block_21], B[block_21], C[block_21], A[block_21].shape)
        add_rec(A[block_22], B[block_22], C[block_22], A[block_22].shape)


m, n = 5, 7
A, B = np.random.rand(m, n), np.random.rand(m, n)

C1 = add(A, B, m, n)

C2 = np.empty((m, n))
add_rec(A, B, C2, [m, n])

print("C1 =\n", C1)
print("C2 =\n", C2)
print((C1 - C2).max(), (C1 - C2).min())
# Out:
# C1 =
#  [[0.83924103 1.23323964 1.0171893  1.05405043 0.88365748 0.56025034
#   1.05750303]
#  [1.06715941 0.65227173 0.77501989 0.9743037  1.34730937 1.18818877
#   1.11369334]
#  [0.20971748 0.45884088 0.97478059 0.72366297 0.84103056 1.54117214
#   1.85750193]
#  [0.47723543 0.74810196 0.5522877  0.29126486 1.07197761 0.62160857
#   1.64183835]
#  [0.98807027 1.22896608 0.57153672 0.9156475  0.56421903 1.03067739
#   1.14795537]]
# C2 =
#  [[0.83924103 1.23323964 1.0171893  1.05405043 0.88365748 0.56025034
#   1.05750303]
#  [1.06715941 0.65227173 0.77501989 0.9743037  1.34730937 1.18818877
#   1.11369334]
#  [0.20971748 0.45884088 0.97478059 0.72366297 0.84103056 1.54117214
#   1.85750193]
#  [0.47723543 0.74810196 0.5522877  0.29126486 1.07197761 0.62160857
#   1.64183835]
#  [0.98807027 1.22896608 0.57153672 0.9156475  0.56421903 1.03067739
#   1.14795537]]
# 0.0 0.0
