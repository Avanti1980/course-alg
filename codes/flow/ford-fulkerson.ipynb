# %%
from queue import PriorityQueue
import itertools


def initialize_flow(c):  # 零初始化
    f = {}
    for u in c:
        f[u] = {}
    for u in c:
        for v in c[u]:
            f[u][v] = 0
    return f


def res_net(c, f):                             # 计算残存网络
    c_f = {}
    for u in c:
        c_f[u] = {}
    for u in c:
        for v in c[u]:
            if f[u][v] == c[u][v]:             # 满流量
                c_f[v][u] = c[u][v]
            elif f[u][v] == 0:                 # 无流量
                c_f[u][v] = c[u][v]
            else:
                c_f[u][v] = c[u][v] - f[u][v]  # 正向边容量等于剩余容量
                c_f[v][u] = f[u][v]            # 反向边容量等于当前流量
    return c_f


def dfs_rec(c_f, pre, visited, u):  # 深度优先 递归
    if u == "t":
        return
    for v in c_f[u].keys():         # 残存网络中 u -> v
        if v not in visited:
            visited.append(v)
            pre[v] = u
            dfs_rec(c_f, pre, visited, v)


def xxfs_iter(c_f, n):
    pre, visited, l = {}, ["s"], ["s"]  # 前驱表 访问标记 用于做搜索的数据结构
    while l:
        u = l.pop(n)                        # 弹出第n个元素
        for v in c_f[u].keys():             # 残存网络中 u -> v
            if v not in visited:
                visited.append(v)
                l.append(v)
                pre[v] = u
                if v == "t":
                    return pre
    return pre


def longest_path(c_f):   # 穷举检查 带环有向图中寻找最长简单路径是NP难的
    nodes = []           # 存储全部中间结点
    for u in c_f:
        if u != "s" and u != "t":
            nodes.append(u)
    pre = {}
    for i in range(len(nodes), 0, -1):
        combination = list(itertools.combinations(nodes, i))  # 按结点数从多到少遍历幂集
        for comb in combination:
            permutation = list(itertools.permutations(comb))  # 对于某个结点子集 生成全排列
            for perm in permutation:
                find_path = True
                if perm[0] not in c_f["s"].keys():  # 如果没有 s -> 第一个点
                    find_path = False
                if "t" not in c_f[perm[-1]].keys():  # 如果没有 最后一个点 -> t
                    find_path = False
                for j in range(1, len(perm)):
                    if perm[j] not in c_f[perm[j - 1]].keys():
                        find_path = False
                        break
                if find_path:
                    pre["t"] = perm[-1]
                    for j in range(len(perm) - 1, 0, -1):
                        pre[perm[j]] = perm[j - 1]
                    pre[perm[0]] = "s"
                    return pre
    return pre


def max_res_cap(c_f):  # 类似于最小生成树的Prim算法
    pre, weight, in_tree, pq = {}, {}, [], PriorityQueue()
    for v in c_f:
        weight[v] = -1  # 记录还没加入树中的点与树中结点的边的最大容量

    pq.put([None, "s"])
    while not pq.empty():
        _, u = pq.get()  # 获取队首元素点u
        if u not in in_tree:
            in_tree.append(u)
            for v in c_f[u].keys():   # 残存网络中 u -> v
                if v not in in_tree and weight[v] < c_f[u][v]:
                    weight[v] = c_f[u][v]
                    pq.put([-weight[v], v])  # 最小优先队列找最大容量 故取反加入
                    pre[v] = u
    return pre


def increase_flow(c_f, f, pre):
    v, path = "t", []
    while True:                      # 根据前驱表生成增广路径
        path.append((pre[v], v))
        v = pre[v]
        if v == "s":
            break
    path.reverse()
    print("增广路径:", path)

    res_cap_edge = []                # 存储增广路径上边的容量
    for u, v in path:
        res_cap_edge.append(c_f[u][v])
        res_cap = min(res_cap_edge)  # 确定残存容量
    print("残存容量:", res_cap)

    for u, v in path:
        if v in f[u].keys():
            f[u][v] += res_cap       # 正向边流量增大
        else:
            f[v][u] -= res_cap       # 反向边流量减小


def calculate_flow(f):
    value = 0
    for v in f["s"].keys():
        value += f["s"][v]
    return value


def ford_fulkerson(c, mode):

    f, i = initialize_flow(c), 1  # 初始化流值为零

    while True:
        print("第%d轮" % i)
        print("当前的流:", f)

        c_f = res_net(c, f)  # 计算残存网络
        print("残存网络:", c_f)

        match mode:
            case 1:  # 深度优先 递归
                pre = {}
                dfs_rec(c_f, pre, ["s"], "s")
            case 2:  # 深度优先 循环 栈
                pre = xxfs_iter(c_f, -1)
            case 3:  # 广度优先 循环 队列 or 最少边数
                pre = xxfs_iter(c_f, 0)
            case 4:  # 最多边数
                pre = longest_path(c_f)
            case 5:  # 最大残存容量
                pre = max_res_cap(c_f)
            case _:
                print("mode取值必须是{1,2,3,4,5}!")
                return

        if "t" not in pre.keys():   # 若汇点、源点已不再连通
            print("最大流值为%d" % calculate_flow(f))
            return
        else:
            increase_flow(c_f, f, pre)

        i += 1


c = {                           # 容量
    "s": {"v1": 16, "v2": 13},  # c(s,v1) = 16, c(s,v2) = 13        v1 -- v3
    "v1": {"v3": 12},           # c(v1,v3) = 12                   / |   / | \
    "v2": {"v1": 4, "v4": 14},  # c(v2,v1) = 4, c(v2,v4) = 14   s   |  /  |  t
    "v3": {"v2": 9, "t": 20},   # c(v3,v2) = 9, c(v3,t) = 20      \ | /   | /
    "v4": {"v3": 7, "t": 4},    # c(v4,v3) = 7, c(v4,t) = 4        v2 -- v4
    "t": {}
}
ford_fulkerson(c, mode=5)
# Out:
# 第1轮
# 当前的流: {'s': {'v1': 0, 'v2': 0}, 'v1': {'v3': 0}, 'v2': {'v1': 0, 'v4': 0}, 'v3': {'v2': 0, 't': 0}, 'v4': {'v3': 0, 't': 0}, 't': {}}
# 残存网络: {'s': {'v1': 16, 'v2': 13}, 'v1': {'v3': 12}, 'v2': {'v1': 4, 'v4': 14}, 'v3': {'v2': 9, 't': 20}, 'v4': {'v3': 7, 't': 4}, 't': {}}
# 增广路径: [('s', 'v1'), ('v1', 'v3'), ('v3', 't')]
# 残存容量: 12
# 第2轮
# 当前的流: {'s': {'v1': 12, 'v2': 0}, 'v1': {'v3': 12}, 'v2': {'v1': 0, 'v4': 0}, 'v3': {'v2': 0, 't': 12}, 'v4': {'v3': 0, 't': 0}, 't': {}}
# 残存网络: {'s': {'v1': 4, 'v2': 13}, 'v1': {'s': 12}, 'v2': {'v1': 4, 'v4': 14}, 'v3': {'v1': 12, 'v2': 9, 't': 8}, 'v4': {'v3': 7, 't': 4}, 't': {'v3': 12}}
# 增广路径: [('s', 'v2'), ('v2', 'v4'), ('v4', 'v3'), ('v3', 't')]
# 残存容量: 7
# 第3轮
# 当前的流: {'s': {'v1': 12, 'v2': 7}, 'v1': {'v3': 12}, 'v2': {'v1': 0, 'v4': 7}, 'v3': {'v2': 0, 't': 19}, 'v4': {'v3': 7, 't': 0}, 't': {}}
# 残存网络: {'s': {'v1': 4, 'v2': 6}, 'v1': {'s': 12}, 'v2': {'s': 7, 'v1': 4, 'v4': 7}, 'v3': {'v1': 12, 'v2': 9, 't': 1, 'v4': 7}, 'v4': {'v2': 7, 't': 4}, 't': {'v3': 19}}
# 增广路径: [('s', 'v2'), ('v2', 'v4'), ('v4', 't')]
# 残存容量: 4
# 第4轮
# 当前的流: {'s': {'v1': 12, 'v2': 11}, 'v1': {'v3': 12}, 'v2': {'v1': 0, 'v4': 11}, 'v3': {'v2': 0, 't': 19}, 'v4': {'v3': 7, 't': 4}, 't': {}}
# 残存网络: {'s': {'v1': 4, 'v2': 2}, 'v1': {'s': 12}, 'v2': {'s': 11, 'v1': 4, 'v4': 3}, 'v3': {'v1': 12, 'v2': 9, 't': 1, 'v4': 7}, 'v4': {'v2': 11}, 't': {'v3': 19, 'v4': 4}}
# 最大流值为23

# %%
c = {                           # 容量                             v
    "s": {"u": 100, "v": 100},  # c(s,u) = 100, c(s,v) = 100    / | \
    "u": {"v": 1, "t": 100},    # c(u,v) = 1, c(u,t) = 100     s  |  t
    "v": {"t": 100},            # c(v,t) = 100                  \ | /
    "t": {}                     # #                               u
}
ford_fulkerson(c, mode=4)
# Out:
# 第1轮
# 当前的流: {'s': {'u': 0, 'v': 0}, 'u': {'v': 0, 't': 0}, 'v': {'t': 0}, 't': {}}
# 残存网络: {'s': {'u': 100, 'v': 100}, 'u': {'v': 1, 't': 100}, 'v': {'t': 100}, 't': {}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第2轮
# 当前的流: {'s': {'u': 1, 'v': 0}, 'u': {'v': 1, 't': 0}, 'v': {'t': 1}, 't': {}}
# 残存网络: {'s': {'u': 99, 'v': 100}, 'u': {'s': 1, 't': 100}, 'v': {'u': 1, 't': 99}, 't': {'v': 1}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第3轮
# 当前的流: {'s': {'u': 1, 'v': 1}, 'u': {'v': 0, 't': 1}, 'v': {'t': 1}, 't': {}}
# 残存网络: {'s': {'u': 99, 'v': 99}, 'u': {'s': 1, 'v': 1, 't': 99}, 'v': {'s': 1, 't': 99}, 't': {'u': 1, 'v': 1}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第4轮
# 当前的流: {'s': {'u': 2, 'v': 1}, 'u': {'v': 1, 't': 1}, 'v': {'t': 2}, 't': {}}
# 残存网络: {'s': {'u': 98, 'v': 99}, 'u': {'s': 2, 't': 99}, 'v': {'s': 1, 'u': 1, 't': 98}, 't': {'u': 1, 'v': 2}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第5轮
# 当前的流: {'s': {'u': 2, 'v': 2}, 'u': {'v': 0, 't': 2}, 'v': {'t': 2}, 't': {}}
# 残存网络: {'s': {'u': 98, 'v': 98}, 'u': {'s': 2, 'v': 1, 't': 98}, 'v': {'s': 2, 't': 98}, 't': {'u': 2, 'v': 2}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第6轮
# 当前的流: {'s': {'u': 3, 'v': 2}, 'u': {'v': 1, 't': 2}, 'v': {'t': 3}, 't': {}}
# 残存网络: {'s': {'u': 97, 'v': 98}, 'u': {'s': 3, 't': 98}, 'v': {'s': 2, 'u': 1, 't': 97}, 't': {'u': 2, 'v': 3}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第7轮
# 当前的流: {'s': {'u': 3, 'v': 3}, 'u': {'v': 0, 't': 3}, 'v': {'t': 3}, 't': {}}
# 残存网络: {'s': {'u': 97, 'v': 97}, 'u': {'s': 3, 'v': 1, 't': 97}, 'v': {'s': 3, 't': 97}, 't': {'u': 3, 'v': 3}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第8轮
# 当前的流: {'s': {'u': 4, 'v': 3}, 'u': {'v': 1, 't': 3}, 'v': {'t': 4}, 't': {}}
# 残存网络: {'s': {'u': 96, 'v': 97}, 'u': {'s': 4, 't': 97}, 'v': {'s': 3, 'u': 1, 't': 96}, 't': {'u': 3, 'v': 4}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第9轮
# 当前的流: {'s': {'u': 4, 'v': 4}, 'u': {'v': 0, 't': 4}, 'v': {'t': 4}, 't': {}}
# 残存网络: {'s': {'u': 96, 'v': 96}, 'u': {'s': 4, 'v': 1, 't': 96}, 'v': {'s': 4, 't': 96}, 't': {'u': 4, 'v': 4}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第10轮
# 当前的流: {'s': {'u': 5, 'v': 4}, 'u': {'v': 1, 't': 4}, 'v': {'t': 5}, 't': {}}
# 残存网络: {'s': {'u': 95, 'v': 96}, 'u': {'s': 5, 't': 96}, 'v': {'s': 4, 'u': 1, 't': 95}, 't': {'u': 4, 'v': 5}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第11轮
# 当前的流: {'s': {'u': 5, 'v': 5}, 'u': {'v': 0, 't': 5}, 'v': {'t': 5}, 't': {}}
# 残存网络: {'s': {'u': 95, 'v': 95}, 'u': {'s': 5, 'v': 1, 't': 95}, 'v': {'s': 5, 't': 95}, 't': {'u': 5, 'v': 5}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第12轮
# 当前的流: {'s': {'u': 6, 'v': 5}, 'u': {'v': 1, 't': 5}, 'v': {'t': 6}, 't': {}}
# 残存网络: {'s': {'u': 94, 'v': 95}, 'u': {'s': 6, 't': 95}, 'v': {'s': 5, 'u': 1, 't': 94}, 't': {'u': 5, 'v': 6}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第13轮
# 当前的流: {'s': {'u': 6, 'v': 6}, 'u': {'v': 0, 't': 6}, 'v': {'t': 6}, 't': {}}
# 残存网络: {'s': {'u': 94, 'v': 94}, 'u': {'s': 6, 'v': 1, 't': 94}, 'v': {'s': 6, 't': 94}, 't': {'u': 6, 'v': 6}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第14轮
# 当前的流: {'s': {'u': 7, 'v': 6}, 'u': {'v': 1, 't': 6}, 'v': {'t': 7}, 't': {}}
# 残存网络: {'s': {'u': 93, 'v': 94}, 'u': {'s': 7, 't': 94}, 'v': {'s': 6, 'u': 1, 't': 93}, 't': {'u': 6, 'v': 7}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第15轮
# 当前的流: {'s': {'u': 7, 'v': 7}, 'u': {'v': 0, 't': 7}, 'v': {'t': 7}, 't': {}}
# 残存网络: {'s': {'u': 93, 'v': 93}, 'u': {'s': 7, 'v': 1, 't': 93}, 'v': {'s': 7, 't': 93}, 't': {'u': 7, 'v': 7}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第16轮
# 当前的流: {'s': {'u': 8, 'v': 7}, 'u': {'v': 1, 't': 7}, 'v': {'t': 8}, 't': {}}
# 残存网络: {'s': {'u': 92, 'v': 93}, 'u': {'s': 8, 't': 93}, 'v': {'s': 7, 'u': 1, 't': 92}, 't': {'u': 7, 'v': 8}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第17轮
# 当前的流: {'s': {'u': 8, 'v': 8}, 'u': {'v': 0, 't': 8}, 'v': {'t': 8}, 't': {}}
# 残存网络: {'s': {'u': 92, 'v': 92}, 'u': {'s': 8, 'v': 1, 't': 92}, 'v': {'s': 8, 't': 92}, 't': {'u': 8, 'v': 8}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第18轮
# 当前的流: {'s': {'u': 9, 'v': 8}, 'u': {'v': 1, 't': 8}, 'v': {'t': 9}, 't': {}}
# 残存网络: {'s': {'u': 91, 'v': 92}, 'u': {'s': 9, 't': 92}, 'v': {'s': 8, 'u': 1, 't': 91}, 't': {'u': 8, 'v': 9}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第19轮
# 当前的流: {'s': {'u': 9, 'v': 9}, 'u': {'v': 0, 't': 9}, 'v': {'t': 9}, 't': {}}
# 残存网络: {'s': {'u': 91, 'v': 91}, 'u': {'s': 9, 'v': 1, 't': 91}, 'v': {'s': 9, 't': 91}, 't': {'u': 9, 'v': 9}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第20轮
# 当前的流: {'s': {'u': 10, 'v': 9}, 'u': {'v': 1, 't': 9}, 'v': {'t': 10}, 't': {}}
# 残存网络: {'s': {'u': 90, 'v': 91}, 'u': {'s': 10, 't': 91}, 'v': {'s': 9, 'u': 1, 't': 90}, 't': {'u': 9, 'v': 10}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第21轮
# 当前的流: {'s': {'u': 10, 'v': 10}, 'u': {'v': 0, 't': 10}, 'v': {'t': 10}, 't': {}}
# 残存网络: {'s': {'u': 90, 'v': 90}, 'u': {'s': 10, 'v': 1, 't': 90}, 'v': {'s': 10, 't': 90}, 't': {'u': 10, 'v': 10}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第22轮
# 当前的流: {'s': {'u': 11, 'v': 10}, 'u': {'v': 1, 't': 10}, 'v': {'t': 11}, 't': {}}
# 残存网络: {'s': {'u': 89, 'v': 90}, 'u': {'s': 11, 't': 90}, 'v': {'s': 10, 'u': 1, 't': 89}, 't': {'u': 10, 'v': 11}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第23轮
# 当前的流: {'s': {'u': 11, 'v': 11}, 'u': {'v': 0, 't': 11}, 'v': {'t': 11}, 't': {}}
# 残存网络: {'s': {'u': 89, 'v': 89}, 'u': {'s': 11, 'v': 1, 't': 89}, 'v': {'s': 11, 't': 89}, 't': {'u': 11, 'v': 11}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第24轮
# 当前的流: {'s': {'u': 12, 'v': 11}, 'u': {'v': 1, 't': 11}, 'v': {'t': 12}, 't': {}}
# 残存网络: {'s': {'u': 88, 'v': 89}, 'u': {'s': 12, 't': 89}, 'v': {'s': 11, 'u': 1, 't': 88}, 't': {'u': 11, 'v': 12}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第25轮
# 当前的流: {'s': {'u': 12, 'v': 12}, 'u': {'v': 0, 't': 12}, 'v': {'t': 12}, 't': {}}
# 残存网络: {'s': {'u': 88, 'v': 88}, 'u': {'s': 12, 'v': 1, 't': 88}, 'v': {'s': 12, 't': 88}, 't': {'u': 12, 'v': 12}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第26轮
# 当前的流: {'s': {'u': 13, 'v': 12}, 'u': {'v': 1, 't': 12}, 'v': {'t': 13}, 't': {}}
# 残存网络: {'s': {'u': 87, 'v': 88}, 'u': {'s': 13, 't': 88}, 'v': {'s': 12, 'u': 1, 't': 87}, 't': {'u': 12, 'v': 13}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第27轮
# 当前的流: {'s': {'u': 13, 'v': 13}, 'u': {'v': 0, 't': 13}, 'v': {'t': 13}, 't': {}}
# 残存网络: {'s': {'u': 87, 'v': 87}, 'u': {'s': 13, 'v': 1, 't': 87}, 'v': {'s': 13, 't': 87}, 't': {'u': 13, 'v': 13}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第28轮
# 当前的流: {'s': {'u': 14, 'v': 13}, 'u': {'v': 1, 't': 13}, 'v': {'t': 14}, 't': {}}
# 残存网络: {'s': {'u': 86, 'v': 87}, 'u': {'s': 14, 't': 87}, 'v': {'s': 13, 'u': 1, 't': 86}, 't': {'u': 13, 'v': 14}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第29轮
# 当前的流: {'s': {'u': 14, 'v': 14}, 'u': {'v': 0, 't': 14}, 'v': {'t': 14}, 't': {}}
# 残存网络: {'s': {'u': 86, 'v': 86}, 'u': {'s': 14, 'v': 1, 't': 86}, 'v': {'s': 14, 't': 86}, 't': {'u': 14, 'v': 14}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第30轮
# 当前的流: {'s': {'u': 15, 'v': 14}, 'u': {'v': 1, 't': 14}, 'v': {'t': 15}, 't': {}}
# 残存网络: {'s': {'u': 85, 'v': 86}, 'u': {'s': 15, 't': 86}, 'v': {'s': 14, 'u': 1, 't': 85}, 't': {'u': 14, 'v': 15}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第31轮
# 当前的流: {'s': {'u': 15, 'v': 15}, 'u': {'v': 0, 't': 15}, 'v': {'t': 15}, 't': {}}
# 残存网络: {'s': {'u': 85, 'v': 85}, 'u': {'s': 15, 'v': 1, 't': 85}, 'v': {'s': 15, 't': 85}, 't': {'u': 15, 'v': 15}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第32轮
# 当前的流: {'s': {'u': 16, 'v': 15}, 'u': {'v': 1, 't': 15}, 'v': {'t': 16}, 't': {}}
# 残存网络: {'s': {'u': 84, 'v': 85}, 'u': {'s': 16, 't': 85}, 'v': {'s': 15, 'u': 1, 't': 84}, 't': {'u': 15, 'v': 16}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第33轮
# 当前的流: {'s': {'u': 16, 'v': 16}, 'u': {'v': 0, 't': 16}, 'v': {'t': 16}, 't': {}}
# 残存网络: {'s': {'u': 84, 'v': 84}, 'u': {'s': 16, 'v': 1, 't': 84}, 'v': {'s': 16, 't': 84}, 't': {'u': 16, 'v': 16}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第34轮
# 当前的流: {'s': {'u': 17, 'v': 16}, 'u': {'v': 1, 't': 16}, 'v': {'t': 17}, 't': {}}
# 残存网络: {'s': {'u': 83, 'v': 84}, 'u': {'s': 17, 't': 84}, 'v': {'s': 16, 'u': 1, 't': 83}, 't': {'u': 16, 'v': 17}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第35轮
# 当前的流: {'s': {'u': 17, 'v': 17}, 'u': {'v': 0, 't': 17}, 'v': {'t': 17}, 't': {}}
# 残存网络: {'s': {'u': 83, 'v': 83}, 'u': {'s': 17, 'v': 1, 't': 83}, 'v': {'s': 17, 't': 83}, 't': {'u': 17, 'v': 17}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第36轮
# 当前的流: {'s': {'u': 18, 'v': 17}, 'u': {'v': 1, 't': 17}, 'v': {'t': 18}, 't': {}}
# 残存网络: {'s': {'u': 82, 'v': 83}, 'u': {'s': 18, 't': 83}, 'v': {'s': 17, 'u': 1, 't': 82}, 't': {'u': 17, 'v': 18}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第37轮
# 当前的流: {'s': {'u': 18, 'v': 18}, 'u': {'v': 0, 't': 18}, 'v': {'t': 18}, 't': {}}
# 残存网络: {'s': {'u': 82, 'v': 82}, 'u': {'s': 18, 'v': 1, 't': 82}, 'v': {'s': 18, 't': 82}, 't': {'u': 18, 'v': 18}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第38轮
# 当前的流: {'s': {'u': 19, 'v': 18}, 'u': {'v': 1, 't': 18}, 'v': {'t': 19}, 't': {}}
# 残存网络: {'s': {'u': 81, 'v': 82}, 'u': {'s': 19, 't': 82}, 'v': {'s': 18, 'u': 1, 't': 81}, 't': {'u': 18, 'v': 19}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第39轮
# 当前的流: {'s': {'u': 19, 'v': 19}, 'u': {'v': 0, 't': 19}, 'v': {'t': 19}, 't': {}}
# 残存网络: {'s': {'u': 81, 'v': 81}, 'u': {'s': 19, 'v': 1, 't': 81}, 'v': {'s': 19, 't': 81}, 't': {'u': 19, 'v': 19}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第40轮
# 当前的流: {'s': {'u': 20, 'v': 19}, 'u': {'v': 1, 't': 19}, 'v': {'t': 20}, 't': {}}
# 残存网络: {'s': {'u': 80, 'v': 81}, 'u': {'s': 20, 't': 81}, 'v': {'s': 19, 'u': 1, 't': 80}, 't': {'u': 19, 'v': 20}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第41轮
# 当前的流: {'s': {'u': 20, 'v': 20}, 'u': {'v': 0, 't': 20}, 'v': {'t': 20}, 't': {}}
# 残存网络: {'s': {'u': 80, 'v': 80}, 'u': {'s': 20, 'v': 1, 't': 80}, 'v': {'s': 20, 't': 80}, 't': {'u': 20, 'v': 20}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第42轮
# 当前的流: {'s': {'u': 21, 'v': 20}, 'u': {'v': 1, 't': 20}, 'v': {'t': 21}, 't': {}}
# 残存网络: {'s': {'u': 79, 'v': 80}, 'u': {'s': 21, 't': 80}, 'v': {'s': 20, 'u': 1, 't': 79}, 't': {'u': 20, 'v': 21}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第43轮
# 当前的流: {'s': {'u': 21, 'v': 21}, 'u': {'v': 0, 't': 21}, 'v': {'t': 21}, 't': {}}
# 残存网络: {'s': {'u': 79, 'v': 79}, 'u': {'s': 21, 'v': 1, 't': 79}, 'v': {'s': 21, 't': 79}, 't': {'u': 21, 'v': 21}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第44轮
# 当前的流: {'s': {'u': 22, 'v': 21}, 'u': {'v': 1, 't': 21}, 'v': {'t': 22}, 't': {}}
# 残存网络: {'s': {'u': 78, 'v': 79}, 'u': {'s': 22, 't': 79}, 'v': {'s': 21, 'u': 1, 't': 78}, 't': {'u': 21, 'v': 22}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第45轮
# 当前的流: {'s': {'u': 22, 'v': 22}, 'u': {'v': 0, 't': 22}, 'v': {'t': 22}, 't': {}}
# 残存网络: {'s': {'u': 78, 'v': 78}, 'u': {'s': 22, 'v': 1, 't': 78}, 'v': {'s': 22, 't': 78}, 't': {'u': 22, 'v': 22}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第46轮
# 当前的流: {'s': {'u': 23, 'v': 22}, 'u': {'v': 1, 't': 22}, 'v': {'t': 23}, 't': {}}
# 残存网络: {'s': {'u': 77, 'v': 78}, 'u': {'s': 23, 't': 78}, 'v': {'s': 22, 'u': 1, 't': 77}, 't': {'u': 22, 'v': 23}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第47轮
# 当前的流: {'s': {'u': 23, 'v': 23}, 'u': {'v': 0, 't': 23}, 'v': {'t': 23}, 't': {}}
# 残存网络: {'s': {'u': 77, 'v': 77}, 'u': {'s': 23, 'v': 1, 't': 77}, 'v': {'s': 23, 't': 77}, 't': {'u': 23, 'v': 23}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第48轮
# 当前的流: {'s': {'u': 24, 'v': 23}, 'u': {'v': 1, 't': 23}, 'v': {'t': 24}, 't': {}}
# 残存网络: {'s': {'u': 76, 'v': 77}, 'u': {'s': 24, 't': 77}, 'v': {'s': 23, 'u': 1, 't': 76}, 't': {'u': 23, 'v': 24}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第49轮
# 当前的流: {'s': {'u': 24, 'v': 24}, 'u': {'v': 0, 't': 24}, 'v': {'t': 24}, 't': {}}
# 残存网络: {'s': {'u': 76, 'v': 76}, 'u': {'s': 24, 'v': 1, 't': 76}, 'v': {'s': 24, 't': 76}, 't': {'u': 24, 'v': 24}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第50轮
# 当前的流: {'s': {'u': 25, 'v': 24}, 'u': {'v': 1, 't': 24}, 'v': {'t': 25}, 't': {}}
# 残存网络: {'s': {'u': 75, 'v': 76}, 'u': {'s': 25, 't': 76}, 'v': {'s': 24, 'u': 1, 't': 75}, 't': {'u': 24, 'v': 25}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第51轮
# 当前的流: {'s': {'u': 25, 'v': 25}, 'u': {'v': 0, 't': 25}, 'v': {'t': 25}, 't': {}}
# 残存网络: {'s': {'u': 75, 'v': 75}, 'u': {'s': 25, 'v': 1, 't': 75}, 'v': {'s': 25, 't': 75}, 't': {'u': 25, 'v': 25}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第52轮
# 当前的流: {'s': {'u': 26, 'v': 25}, 'u': {'v': 1, 't': 25}, 'v': {'t': 26}, 't': {}}
# 残存网络: {'s': {'u': 74, 'v': 75}, 'u': {'s': 26, 't': 75}, 'v': {'s': 25, 'u': 1, 't': 74}, 't': {'u': 25, 'v': 26}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第53轮
# 当前的流: {'s': {'u': 26, 'v': 26}, 'u': {'v': 0, 't': 26}, 'v': {'t': 26}, 't': {}}
# 残存网络: {'s': {'u': 74, 'v': 74}, 'u': {'s': 26, 'v': 1, 't': 74}, 'v': {'s': 26, 't': 74}, 't': {'u': 26, 'v': 26}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第54轮
# 当前的流: {'s': {'u': 27, 'v': 26}, 'u': {'v': 1, 't': 26}, 'v': {'t': 27}, 't': {}}
# 残存网络: {'s': {'u': 73, 'v': 74}, 'u': {'s': 27, 't': 74}, 'v': {'s': 26, 'u': 1, 't': 73}, 't': {'u': 26, 'v': 27}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第55轮
# 当前的流: {'s': {'u': 27, 'v': 27}, 'u': {'v': 0, 't': 27}, 'v': {'t': 27}, 't': {}}
# 残存网络: {'s': {'u': 73, 'v': 73}, 'u': {'s': 27, 'v': 1, 't': 73}, 'v': {'s': 27, 't': 73}, 't': {'u': 27, 'v': 27}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第56轮
# 当前的流: {'s': {'u': 28, 'v': 27}, 'u': {'v': 1, 't': 27}, 'v': {'t': 28}, 't': {}}
# 残存网络: {'s': {'u': 72, 'v': 73}, 'u': {'s': 28, 't': 73}, 'v': {'s': 27, 'u': 1, 't': 72}, 't': {'u': 27, 'v': 28}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第57轮
# 当前的流: {'s': {'u': 28, 'v': 28}, 'u': {'v': 0, 't': 28}, 'v': {'t': 28}, 't': {}}
# 残存网络: {'s': {'u': 72, 'v': 72}, 'u': {'s': 28, 'v': 1, 't': 72}, 'v': {'s': 28, 't': 72}, 't': {'u': 28, 'v': 28}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第58轮
# 当前的流: {'s': {'u': 29, 'v': 28}, 'u': {'v': 1, 't': 28}, 'v': {'t': 29}, 't': {}}
# 残存网络: {'s': {'u': 71, 'v': 72}, 'u': {'s': 29, 't': 72}, 'v': {'s': 28, 'u': 1, 't': 71}, 't': {'u': 28, 'v': 29}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第59轮
# 当前的流: {'s': {'u': 29, 'v': 29}, 'u': {'v': 0, 't': 29}, 'v': {'t': 29}, 't': {}}
# 残存网络: {'s': {'u': 71, 'v': 71}, 'u': {'s': 29, 'v': 1, 't': 71}, 'v': {'s': 29, 't': 71}, 't': {'u': 29, 'v': 29}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第60轮
# 当前的流: {'s': {'u': 30, 'v': 29}, 'u': {'v': 1, 't': 29}, 'v': {'t': 30}, 't': {}}
# 残存网络: {'s': {'u': 70, 'v': 71}, 'u': {'s': 30, 't': 71}, 'v': {'s': 29, 'u': 1, 't': 70}, 't': {'u': 29, 'v': 30}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第61轮
# 当前的流: {'s': {'u': 30, 'v': 30}, 'u': {'v': 0, 't': 30}, 'v': {'t': 30}, 't': {}}
# 残存网络: {'s': {'u': 70, 'v': 70}, 'u': {'s': 30, 'v': 1, 't': 70}, 'v': {'s': 30, 't': 70}, 't': {'u': 30, 'v': 30}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第62轮
# 当前的流: {'s': {'u': 31, 'v': 30}, 'u': {'v': 1, 't': 30}, 'v': {'t': 31}, 't': {}}
# 残存网络: {'s': {'u': 69, 'v': 70}, 'u': {'s': 31, 't': 70}, 'v': {'s': 30, 'u': 1, 't': 69}, 't': {'u': 30, 'v': 31}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第63轮
# 当前的流: {'s': {'u': 31, 'v': 31}, 'u': {'v': 0, 't': 31}, 'v': {'t': 31}, 't': {}}
# 残存网络: {'s': {'u': 69, 'v': 69}, 'u': {'s': 31, 'v': 1, 't': 69}, 'v': {'s': 31, 't': 69}, 't': {'u': 31, 'v': 31}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第64轮
# 当前的流: {'s': {'u': 32, 'v': 31}, 'u': {'v': 1, 't': 31}, 'v': {'t': 32}, 't': {}}
# 残存网络: {'s': {'u': 68, 'v': 69}, 'u': {'s': 32, 't': 69}, 'v': {'s': 31, 'u': 1, 't': 68}, 't': {'u': 31, 'v': 32}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第65轮
# 当前的流: {'s': {'u': 32, 'v': 32}, 'u': {'v': 0, 't': 32}, 'v': {'t': 32}, 't': {}}
# 残存网络: {'s': {'u': 68, 'v': 68}, 'u': {'s': 32, 'v': 1, 't': 68}, 'v': {'s': 32, 't': 68}, 't': {'u': 32, 'v': 32}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第66轮
# 当前的流: {'s': {'u': 33, 'v': 32}, 'u': {'v': 1, 't': 32}, 'v': {'t': 33}, 't': {}}
# 残存网络: {'s': {'u': 67, 'v': 68}, 'u': {'s': 33, 't': 68}, 'v': {'s': 32, 'u': 1, 't': 67}, 't': {'u': 32, 'v': 33}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第67轮
# 当前的流: {'s': {'u': 33, 'v': 33}, 'u': {'v': 0, 't': 33}, 'v': {'t': 33}, 't': {}}
# 残存网络: {'s': {'u': 67, 'v': 67}, 'u': {'s': 33, 'v': 1, 't': 67}, 'v': {'s': 33, 't': 67}, 't': {'u': 33, 'v': 33}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第68轮
# 当前的流: {'s': {'u': 34, 'v': 33}, 'u': {'v': 1, 't': 33}, 'v': {'t': 34}, 't': {}}
# 残存网络: {'s': {'u': 66, 'v': 67}, 'u': {'s': 34, 't': 67}, 'v': {'s': 33, 'u': 1, 't': 66}, 't': {'u': 33, 'v': 34}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第69轮
# 当前的流: {'s': {'u': 34, 'v': 34}, 'u': {'v': 0, 't': 34}, 'v': {'t': 34}, 't': {}}
# 残存网络: {'s': {'u': 66, 'v': 66}, 'u': {'s': 34, 'v': 1, 't': 66}, 'v': {'s': 34, 't': 66}, 't': {'u': 34, 'v': 34}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第70轮
# 当前的流: {'s': {'u': 35, 'v': 34}, 'u': {'v': 1, 't': 34}, 'v': {'t': 35}, 't': {}}
# 残存网络: {'s': {'u': 65, 'v': 66}, 'u': {'s': 35, 't': 66}, 'v': {'s': 34, 'u': 1, 't': 65}, 't': {'u': 34, 'v': 35}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第71轮
# 当前的流: {'s': {'u': 35, 'v': 35}, 'u': {'v': 0, 't': 35}, 'v': {'t': 35}, 't': {}}
# 残存网络: {'s': {'u': 65, 'v': 65}, 'u': {'s': 35, 'v': 1, 't': 65}, 'v': {'s': 35, 't': 65}, 't': {'u': 35, 'v': 35}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第72轮
# 当前的流: {'s': {'u': 36, 'v': 35}, 'u': {'v': 1, 't': 35}, 'v': {'t': 36}, 't': {}}
# 残存网络: {'s': {'u': 64, 'v': 65}, 'u': {'s': 36, 't': 65}, 'v': {'s': 35, 'u': 1, 't': 64}, 't': {'u': 35, 'v': 36}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第73轮
# 当前的流: {'s': {'u': 36, 'v': 36}, 'u': {'v': 0, 't': 36}, 'v': {'t': 36}, 't': {}}
# 残存网络: {'s': {'u': 64, 'v': 64}, 'u': {'s': 36, 'v': 1, 't': 64}, 'v': {'s': 36, 't': 64}, 't': {'u': 36, 'v': 36}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第74轮
# 当前的流: {'s': {'u': 37, 'v': 36}, 'u': {'v': 1, 't': 36}, 'v': {'t': 37}, 't': {}}
# 残存网络: {'s': {'u': 63, 'v': 64}, 'u': {'s': 37, 't': 64}, 'v': {'s': 36, 'u': 1, 't': 63}, 't': {'u': 36, 'v': 37}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第75轮
# 当前的流: {'s': {'u': 37, 'v': 37}, 'u': {'v': 0, 't': 37}, 'v': {'t': 37}, 't': {}}
# 残存网络: {'s': {'u': 63, 'v': 63}, 'u': {'s': 37, 'v': 1, 't': 63}, 'v': {'s': 37, 't': 63}, 't': {'u': 37, 'v': 37}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第76轮
# 当前的流: {'s': {'u': 38, 'v': 37}, 'u': {'v': 1, 't': 37}, 'v': {'t': 38}, 't': {}}
# 残存网络: {'s': {'u': 62, 'v': 63}, 'u': {'s': 38, 't': 63}, 'v': {'s': 37, 'u': 1, 't': 62}, 't': {'u': 37, 'v': 38}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第77轮
# 当前的流: {'s': {'u': 38, 'v': 38}, 'u': {'v': 0, 't': 38}, 'v': {'t': 38}, 't': {}}
# 残存网络: {'s': {'u': 62, 'v': 62}, 'u': {'s': 38, 'v': 1, 't': 62}, 'v': {'s': 38, 't': 62}, 't': {'u': 38, 'v': 38}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第78轮
# 当前的流: {'s': {'u': 39, 'v': 38}, 'u': {'v': 1, 't': 38}, 'v': {'t': 39}, 't': {}}
# 残存网络: {'s': {'u': 61, 'v': 62}, 'u': {'s': 39, 't': 62}, 'v': {'s': 38, 'u': 1, 't': 61}, 't': {'u': 38, 'v': 39}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第79轮
# 当前的流: {'s': {'u': 39, 'v': 39}, 'u': {'v': 0, 't': 39}, 'v': {'t': 39}, 't': {}}
# 残存网络: {'s': {'u': 61, 'v': 61}, 'u': {'s': 39, 'v': 1, 't': 61}, 'v': {'s': 39, 't': 61}, 't': {'u': 39, 'v': 39}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第80轮
# 当前的流: {'s': {'u': 40, 'v': 39}, 'u': {'v': 1, 't': 39}, 'v': {'t': 40}, 't': {}}
# 残存网络: {'s': {'u': 60, 'v': 61}, 'u': {'s': 40, 't': 61}, 'v': {'s': 39, 'u': 1, 't': 60}, 't': {'u': 39, 'v': 40}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第81轮
# 当前的流: {'s': {'u': 40, 'v': 40}, 'u': {'v': 0, 't': 40}, 'v': {'t': 40}, 't': {}}
# 残存网络: {'s': {'u': 60, 'v': 60}, 'u': {'s': 40, 'v': 1, 't': 60}, 'v': {'s': 40, 't': 60}, 't': {'u': 40, 'v': 40}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第82轮
# 当前的流: {'s': {'u': 41, 'v': 40}, 'u': {'v': 1, 't': 40}, 'v': {'t': 41}, 't': {}}
# 残存网络: {'s': {'u': 59, 'v': 60}, 'u': {'s': 41, 't': 60}, 'v': {'s': 40, 'u': 1, 't': 59}, 't': {'u': 40, 'v': 41}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第83轮
# 当前的流: {'s': {'u': 41, 'v': 41}, 'u': {'v': 0, 't': 41}, 'v': {'t': 41}, 't': {}}
# 残存网络: {'s': {'u': 59, 'v': 59}, 'u': {'s': 41, 'v': 1, 't': 59}, 'v': {'s': 41, 't': 59}, 't': {'u': 41, 'v': 41}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第84轮
# 当前的流: {'s': {'u': 42, 'v': 41}, 'u': {'v': 1, 't': 41}, 'v': {'t': 42}, 't': {}}
# 残存网络: {'s': {'u': 58, 'v': 59}, 'u': {'s': 42, 't': 59}, 'v': {'s': 41, 'u': 1, 't': 58}, 't': {'u': 41, 'v': 42}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第85轮
# 当前的流: {'s': {'u': 42, 'v': 42}, 'u': {'v': 0, 't': 42}, 'v': {'t': 42}, 't': {}}
# 残存网络: {'s': {'u': 58, 'v': 58}, 'u': {'s': 42, 'v': 1, 't': 58}, 'v': {'s': 42, 't': 58}, 't': {'u': 42, 'v': 42}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第86轮
# 当前的流: {'s': {'u': 43, 'v': 42}, 'u': {'v': 1, 't': 42}, 'v': {'t': 43}, 't': {}}
# 残存网络: {'s': {'u': 57, 'v': 58}, 'u': {'s': 43, 't': 58}, 'v': {'s': 42, 'u': 1, 't': 57}, 't': {'u': 42, 'v': 43}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第87轮
# 当前的流: {'s': {'u': 43, 'v': 43}, 'u': {'v': 0, 't': 43}, 'v': {'t': 43}, 't': {}}
# 残存网络: {'s': {'u': 57, 'v': 57}, 'u': {'s': 43, 'v': 1, 't': 57}, 'v': {'s': 43, 't': 57}, 't': {'u': 43, 'v': 43}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第88轮
# 当前的流: {'s': {'u': 44, 'v': 43}, 'u': {'v': 1, 't': 43}, 'v': {'t': 44}, 't': {}}
# 残存网络: {'s': {'u': 56, 'v': 57}, 'u': {'s': 44, 't': 57}, 'v': {'s': 43, 'u': 1, 't': 56}, 't': {'u': 43, 'v': 44}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第89轮
# 当前的流: {'s': {'u': 44, 'v': 44}, 'u': {'v': 0, 't': 44}, 'v': {'t': 44}, 't': {}}
# 残存网络: {'s': {'u': 56, 'v': 56}, 'u': {'s': 44, 'v': 1, 't': 56}, 'v': {'s': 44, 't': 56}, 't': {'u': 44, 'v': 44}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第90轮
# 当前的流: {'s': {'u': 45, 'v': 44}, 'u': {'v': 1, 't': 44}, 'v': {'t': 45}, 't': {}}
# 残存网络: {'s': {'u': 55, 'v': 56}, 'u': {'s': 45, 't': 56}, 'v': {'s': 44, 'u': 1, 't': 55}, 't': {'u': 44, 'v': 45}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第91轮
# 当前的流: {'s': {'u': 45, 'v': 45}, 'u': {'v': 0, 't': 45}, 'v': {'t': 45}, 't': {}}
# 残存网络: {'s': {'u': 55, 'v': 55}, 'u': {'s': 45, 'v': 1, 't': 55}, 'v': {'s': 45, 't': 55}, 't': {'u': 45, 'v': 45}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第92轮
# 当前的流: {'s': {'u': 46, 'v': 45}, 'u': {'v': 1, 't': 45}, 'v': {'t': 46}, 't': {}}
# 残存网络: {'s': {'u': 54, 'v': 55}, 'u': {'s': 46, 't': 55}, 'v': {'s': 45, 'u': 1, 't': 54}, 't': {'u': 45, 'v': 46}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第93轮
# 当前的流: {'s': {'u': 46, 'v': 46}, 'u': {'v': 0, 't': 46}, 'v': {'t': 46}, 't': {}}
# 残存网络: {'s': {'u': 54, 'v': 54}, 'u': {'s': 46, 'v': 1, 't': 54}, 'v': {'s': 46, 't': 54}, 't': {'u': 46, 'v': 46}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第94轮
# 当前的流: {'s': {'u': 47, 'v': 46}, 'u': {'v': 1, 't': 46}, 'v': {'t': 47}, 't': {}}
# 残存网络: {'s': {'u': 53, 'v': 54}, 'u': {'s': 47, 't': 54}, 'v': {'s': 46, 'u': 1, 't': 53}, 't': {'u': 46, 'v': 47}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第95轮
# 当前的流: {'s': {'u': 47, 'v': 47}, 'u': {'v': 0, 't': 47}, 'v': {'t': 47}, 't': {}}
# 残存网络: {'s': {'u': 53, 'v': 53}, 'u': {'s': 47, 'v': 1, 't': 53}, 'v': {'s': 47, 't': 53}, 't': {'u': 47, 'v': 47}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第96轮
# 当前的流: {'s': {'u': 48, 'v': 47}, 'u': {'v': 1, 't': 47}, 'v': {'t': 48}, 't': {}}
# 残存网络: {'s': {'u': 52, 'v': 53}, 'u': {'s': 48, 't': 53}, 'v': {'s': 47, 'u': 1, 't': 52}, 't': {'u': 47, 'v': 48}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第97轮
# 当前的流: {'s': {'u': 48, 'v': 48}, 'u': {'v': 0, 't': 48}, 'v': {'t': 48}, 't': {}}
# 残存网络: {'s': {'u': 52, 'v': 52}, 'u': {'s': 48, 'v': 1, 't': 52}, 'v': {'s': 48, 't': 52}, 't': {'u': 48, 'v': 48}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第98轮
# 当前的流: {'s': {'u': 49, 'v': 48}, 'u': {'v': 1, 't': 48}, 'v': {'t': 49}, 't': {}}
# 残存网络: {'s': {'u': 51, 'v': 52}, 'u': {'s': 49, 't': 52}, 'v': {'s': 48, 'u': 1, 't': 51}, 't': {'u': 48, 'v': 49}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第99轮
# 当前的流: {'s': {'u': 49, 'v': 49}, 'u': {'v': 0, 't': 49}, 'v': {'t': 49}, 't': {}}
# 残存网络: {'s': {'u': 51, 'v': 51}, 'u': {'s': 49, 'v': 1, 't': 51}, 'v': {'s': 49, 't': 51}, 't': {'u': 49, 'v': 49}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第100轮
# 当前的流: {'s': {'u': 50, 'v': 49}, 'u': {'v': 1, 't': 49}, 'v': {'t': 50}, 't': {}}
# 残存网络: {'s': {'u': 50, 'v': 51}, 'u': {'s': 50, 't': 51}, 'v': {'s': 49, 'u': 1, 't': 50}, 't': {'u': 49, 'v': 50}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第101轮
# 当前的流: {'s': {'u': 50, 'v': 50}, 'u': {'v': 0, 't': 50}, 'v': {'t': 50}, 't': {}}
# 残存网络: {'s': {'u': 50, 'v': 50}, 'u': {'s': 50, 'v': 1, 't': 50}, 'v': {'s': 50, 't': 50}, 't': {'u': 50, 'v': 50}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第102轮
# 当前的流: {'s': {'u': 51, 'v': 50}, 'u': {'v': 1, 't': 50}, 'v': {'t': 51}, 't': {}}
# 残存网络: {'s': {'u': 49, 'v': 50}, 'u': {'s': 51, 't': 50}, 'v': {'s': 50, 'u': 1, 't': 49}, 't': {'u': 50, 'v': 51}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第103轮
# 当前的流: {'s': {'u': 51, 'v': 51}, 'u': {'v': 0, 't': 51}, 'v': {'t': 51}, 't': {}}
# 残存网络: {'s': {'u': 49, 'v': 49}, 'u': {'s': 51, 'v': 1, 't': 49}, 'v': {'s': 51, 't': 49}, 't': {'u': 51, 'v': 51}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第104轮
# 当前的流: {'s': {'u': 52, 'v': 51}, 'u': {'v': 1, 't': 51}, 'v': {'t': 52}, 't': {}}
# 残存网络: {'s': {'u': 48, 'v': 49}, 'u': {'s': 52, 't': 49}, 'v': {'s': 51, 'u': 1, 't': 48}, 't': {'u': 51, 'v': 52}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第105轮
# 当前的流: {'s': {'u': 52, 'v': 52}, 'u': {'v': 0, 't': 52}, 'v': {'t': 52}, 't': {}}
# 残存网络: {'s': {'u': 48, 'v': 48}, 'u': {'s': 52, 'v': 1, 't': 48}, 'v': {'s': 52, 't': 48}, 't': {'u': 52, 'v': 52}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第106轮
# 当前的流: {'s': {'u': 53, 'v': 52}, 'u': {'v': 1, 't': 52}, 'v': {'t': 53}, 't': {}}
# 残存网络: {'s': {'u': 47, 'v': 48}, 'u': {'s': 53, 't': 48}, 'v': {'s': 52, 'u': 1, 't': 47}, 't': {'u': 52, 'v': 53}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第107轮
# 当前的流: {'s': {'u': 53, 'v': 53}, 'u': {'v': 0, 't': 53}, 'v': {'t': 53}, 't': {}}
# 残存网络: {'s': {'u': 47, 'v': 47}, 'u': {'s': 53, 'v': 1, 't': 47}, 'v': {'s': 53, 't': 47}, 't': {'u': 53, 'v': 53}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第108轮
# 当前的流: {'s': {'u': 54, 'v': 53}, 'u': {'v': 1, 't': 53}, 'v': {'t': 54}, 't': {}}
# 残存网络: {'s': {'u': 46, 'v': 47}, 'u': {'s': 54, 't': 47}, 'v': {'s': 53, 'u': 1, 't': 46}, 't': {'u': 53, 'v': 54}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第109轮
# 当前的流: {'s': {'u': 54, 'v': 54}, 'u': {'v': 0, 't': 54}, 'v': {'t': 54}, 't': {}}
# 残存网络: {'s': {'u': 46, 'v': 46}, 'u': {'s': 54, 'v': 1, 't': 46}, 'v': {'s': 54, 't': 46}, 't': {'u': 54, 'v': 54}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第110轮
# 当前的流: {'s': {'u': 55, 'v': 54}, 'u': {'v': 1, 't': 54}, 'v': {'t': 55}, 't': {}}
# 残存网络: {'s': {'u': 45, 'v': 46}, 'u': {'s': 55, 't': 46}, 'v': {'s': 54, 'u': 1, 't': 45}, 't': {'u': 54, 'v': 55}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第111轮
# 当前的流: {'s': {'u': 55, 'v': 55}, 'u': {'v': 0, 't': 55}, 'v': {'t': 55}, 't': {}}
# 残存网络: {'s': {'u': 45, 'v': 45}, 'u': {'s': 55, 'v': 1, 't': 45}, 'v': {'s': 55, 't': 45}, 't': {'u': 55, 'v': 55}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第112轮
# 当前的流: {'s': {'u': 56, 'v': 55}, 'u': {'v': 1, 't': 55}, 'v': {'t': 56}, 't': {}}
# 残存网络: {'s': {'u': 44, 'v': 45}, 'u': {'s': 56, 't': 45}, 'v': {'s': 55, 'u': 1, 't': 44}, 't': {'u': 55, 'v': 56}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第113轮
# 当前的流: {'s': {'u': 56, 'v': 56}, 'u': {'v': 0, 't': 56}, 'v': {'t': 56}, 't': {}}
# 残存网络: {'s': {'u': 44, 'v': 44}, 'u': {'s': 56, 'v': 1, 't': 44}, 'v': {'s': 56, 't': 44}, 't': {'u': 56, 'v': 56}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第114轮
# 当前的流: {'s': {'u': 57, 'v': 56}, 'u': {'v': 1, 't': 56}, 'v': {'t': 57}, 't': {}}
# 残存网络: {'s': {'u': 43, 'v': 44}, 'u': {'s': 57, 't': 44}, 'v': {'s': 56, 'u': 1, 't': 43}, 't': {'u': 56, 'v': 57}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第115轮
# 当前的流: {'s': {'u': 57, 'v': 57}, 'u': {'v': 0, 't': 57}, 'v': {'t': 57}, 't': {}}
# 残存网络: {'s': {'u': 43, 'v': 43}, 'u': {'s': 57, 'v': 1, 't': 43}, 'v': {'s': 57, 't': 43}, 't': {'u': 57, 'v': 57}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第116轮
# 当前的流: {'s': {'u': 58, 'v': 57}, 'u': {'v': 1, 't': 57}, 'v': {'t': 58}, 't': {}}
# 残存网络: {'s': {'u': 42, 'v': 43}, 'u': {'s': 58, 't': 43}, 'v': {'s': 57, 'u': 1, 't': 42}, 't': {'u': 57, 'v': 58}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第117轮
# 当前的流: {'s': {'u': 58, 'v': 58}, 'u': {'v': 0, 't': 58}, 'v': {'t': 58}, 't': {}}
# 残存网络: {'s': {'u': 42, 'v': 42}, 'u': {'s': 58, 'v': 1, 't': 42}, 'v': {'s': 58, 't': 42}, 't': {'u': 58, 'v': 58}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第118轮
# 当前的流: {'s': {'u': 59, 'v': 58}, 'u': {'v': 1, 't': 58}, 'v': {'t': 59}, 't': {}}
# 残存网络: {'s': {'u': 41, 'v': 42}, 'u': {'s': 59, 't': 42}, 'v': {'s': 58, 'u': 1, 't': 41}, 't': {'u': 58, 'v': 59}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第119轮
# 当前的流: {'s': {'u': 59, 'v': 59}, 'u': {'v': 0, 't': 59}, 'v': {'t': 59}, 't': {}}
# 残存网络: {'s': {'u': 41, 'v': 41}, 'u': {'s': 59, 'v': 1, 't': 41}, 'v': {'s': 59, 't': 41}, 't': {'u': 59, 'v': 59}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第120轮
# 当前的流: {'s': {'u': 60, 'v': 59}, 'u': {'v': 1, 't': 59}, 'v': {'t': 60}, 't': {}}
# 残存网络: {'s': {'u': 40, 'v': 41}, 'u': {'s': 60, 't': 41}, 'v': {'s': 59, 'u': 1, 't': 40}, 't': {'u': 59, 'v': 60}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第121轮
# 当前的流: {'s': {'u': 60, 'v': 60}, 'u': {'v': 0, 't': 60}, 'v': {'t': 60}, 't': {}}
# 残存网络: {'s': {'u': 40, 'v': 40}, 'u': {'s': 60, 'v': 1, 't': 40}, 'v': {'s': 60, 't': 40}, 't': {'u': 60, 'v': 60}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第122轮
# 当前的流: {'s': {'u': 61, 'v': 60}, 'u': {'v': 1, 't': 60}, 'v': {'t': 61}, 't': {}}
# 残存网络: {'s': {'u': 39, 'v': 40}, 'u': {'s': 61, 't': 40}, 'v': {'s': 60, 'u': 1, 't': 39}, 't': {'u': 60, 'v': 61}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第123轮
# 当前的流: {'s': {'u': 61, 'v': 61}, 'u': {'v': 0, 't': 61}, 'v': {'t': 61}, 't': {}}
# 残存网络: {'s': {'u': 39, 'v': 39}, 'u': {'s': 61, 'v': 1, 't': 39}, 'v': {'s': 61, 't': 39}, 't': {'u': 61, 'v': 61}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第124轮
# 当前的流: {'s': {'u': 62, 'v': 61}, 'u': {'v': 1, 't': 61}, 'v': {'t': 62}, 't': {}}
# 残存网络: {'s': {'u': 38, 'v': 39}, 'u': {'s': 62, 't': 39}, 'v': {'s': 61, 'u': 1, 't': 38}, 't': {'u': 61, 'v': 62}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第125轮
# 当前的流: {'s': {'u': 62, 'v': 62}, 'u': {'v': 0, 't': 62}, 'v': {'t': 62}, 't': {}}
# 残存网络: {'s': {'u': 38, 'v': 38}, 'u': {'s': 62, 'v': 1, 't': 38}, 'v': {'s': 62, 't': 38}, 't': {'u': 62, 'v': 62}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第126轮
# 当前的流: {'s': {'u': 63, 'v': 62}, 'u': {'v': 1, 't': 62}, 'v': {'t': 63}, 't': {}}
# 残存网络: {'s': {'u': 37, 'v': 38}, 'u': {'s': 63, 't': 38}, 'v': {'s': 62, 'u': 1, 't': 37}, 't': {'u': 62, 'v': 63}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第127轮
# 当前的流: {'s': {'u': 63, 'v': 63}, 'u': {'v': 0, 't': 63}, 'v': {'t': 63}, 't': {}}
# 残存网络: {'s': {'u': 37, 'v': 37}, 'u': {'s': 63, 'v': 1, 't': 37}, 'v': {'s': 63, 't': 37}, 't': {'u': 63, 'v': 63}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第128轮
# 当前的流: {'s': {'u': 64, 'v': 63}, 'u': {'v': 1, 't': 63}, 'v': {'t': 64}, 't': {}}
# 残存网络: {'s': {'u': 36, 'v': 37}, 'u': {'s': 64, 't': 37}, 'v': {'s': 63, 'u': 1, 't': 36}, 't': {'u': 63, 'v': 64}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第129轮
# 当前的流: {'s': {'u': 64, 'v': 64}, 'u': {'v': 0, 't': 64}, 'v': {'t': 64}, 't': {}}
# 残存网络: {'s': {'u': 36, 'v': 36}, 'u': {'s': 64, 'v': 1, 't': 36}, 'v': {'s': 64, 't': 36}, 't': {'u': 64, 'v': 64}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第130轮
# 当前的流: {'s': {'u': 65, 'v': 64}, 'u': {'v': 1, 't': 64}, 'v': {'t': 65}, 't': {}}
# 残存网络: {'s': {'u': 35, 'v': 36}, 'u': {'s': 65, 't': 36}, 'v': {'s': 64, 'u': 1, 't': 35}, 't': {'u': 64, 'v': 65}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第131轮
# 当前的流: {'s': {'u': 65, 'v': 65}, 'u': {'v': 0, 't': 65}, 'v': {'t': 65}, 't': {}}
# 残存网络: {'s': {'u': 35, 'v': 35}, 'u': {'s': 65, 'v': 1, 't': 35}, 'v': {'s': 65, 't': 35}, 't': {'u': 65, 'v': 65}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第132轮
# 当前的流: {'s': {'u': 66, 'v': 65}, 'u': {'v': 1, 't': 65}, 'v': {'t': 66}, 't': {}}
# 残存网络: {'s': {'u': 34, 'v': 35}, 'u': {'s': 66, 't': 35}, 'v': {'s': 65, 'u': 1, 't': 34}, 't': {'u': 65, 'v': 66}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第133轮
# 当前的流: {'s': {'u': 66, 'v': 66}, 'u': {'v': 0, 't': 66}, 'v': {'t': 66}, 't': {}}
# 残存网络: {'s': {'u': 34, 'v': 34}, 'u': {'s': 66, 'v': 1, 't': 34}, 'v': {'s': 66, 't': 34}, 't': {'u': 66, 'v': 66}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第134轮
# 当前的流: {'s': {'u': 67, 'v': 66}, 'u': {'v': 1, 't': 66}, 'v': {'t': 67}, 't': {}}
# 残存网络: {'s': {'u': 33, 'v': 34}, 'u': {'s': 67, 't': 34}, 'v': {'s': 66, 'u': 1, 't': 33}, 't': {'u': 66, 'v': 67}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第135轮
# 当前的流: {'s': {'u': 67, 'v': 67}, 'u': {'v': 0, 't': 67}, 'v': {'t': 67}, 't': {}}
# 残存网络: {'s': {'u': 33, 'v': 33}, 'u': {'s': 67, 'v': 1, 't': 33}, 'v': {'s': 67, 't': 33}, 't': {'u': 67, 'v': 67}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第136轮
# 当前的流: {'s': {'u': 68, 'v': 67}, 'u': {'v': 1, 't': 67}, 'v': {'t': 68}, 't': {}}
# 残存网络: {'s': {'u': 32, 'v': 33}, 'u': {'s': 68, 't': 33}, 'v': {'s': 67, 'u': 1, 't': 32}, 't': {'u': 67, 'v': 68}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第137轮
# 当前的流: {'s': {'u': 68, 'v': 68}, 'u': {'v': 0, 't': 68}, 'v': {'t': 68}, 't': {}}
# 残存网络: {'s': {'u': 32, 'v': 32}, 'u': {'s': 68, 'v': 1, 't': 32}, 'v': {'s': 68, 't': 32}, 't': {'u': 68, 'v': 68}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第138轮
# 当前的流: {'s': {'u': 69, 'v': 68}, 'u': {'v': 1, 't': 68}, 'v': {'t': 69}, 't': {}}
# 残存网络: {'s': {'u': 31, 'v': 32}, 'u': {'s': 69, 't': 32}, 'v': {'s': 68, 'u': 1, 't': 31}, 't': {'u': 68, 'v': 69}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第139轮
# 当前的流: {'s': {'u': 69, 'v': 69}, 'u': {'v': 0, 't': 69}, 'v': {'t': 69}, 't': {}}
# 残存网络: {'s': {'u': 31, 'v': 31}, 'u': {'s': 69, 'v': 1, 't': 31}, 'v': {'s': 69, 't': 31}, 't': {'u': 69, 'v': 69}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第140轮
# 当前的流: {'s': {'u': 70, 'v': 69}, 'u': {'v': 1, 't': 69}, 'v': {'t': 70}, 't': {}}
# 残存网络: {'s': {'u': 30, 'v': 31}, 'u': {'s': 70, 't': 31}, 'v': {'s': 69, 'u': 1, 't': 30}, 't': {'u': 69, 'v': 70}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第141轮
# 当前的流: {'s': {'u': 70, 'v': 70}, 'u': {'v': 0, 't': 70}, 'v': {'t': 70}, 't': {}}
# 残存网络: {'s': {'u': 30, 'v': 30}, 'u': {'s': 70, 'v': 1, 't': 30}, 'v': {'s': 70, 't': 30}, 't': {'u': 70, 'v': 70}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第142轮
# 当前的流: {'s': {'u': 71, 'v': 70}, 'u': {'v': 1, 't': 70}, 'v': {'t': 71}, 't': {}}
# 残存网络: {'s': {'u': 29, 'v': 30}, 'u': {'s': 71, 't': 30}, 'v': {'s': 70, 'u': 1, 't': 29}, 't': {'u': 70, 'v': 71}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第143轮
# 当前的流: {'s': {'u': 71, 'v': 71}, 'u': {'v': 0, 't': 71}, 'v': {'t': 71}, 't': {}}
# 残存网络: {'s': {'u': 29, 'v': 29}, 'u': {'s': 71, 'v': 1, 't': 29}, 'v': {'s': 71, 't': 29}, 't': {'u': 71, 'v': 71}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第144轮
# 当前的流: {'s': {'u': 72, 'v': 71}, 'u': {'v': 1, 't': 71}, 'v': {'t': 72}, 't': {}}
# 残存网络: {'s': {'u': 28, 'v': 29}, 'u': {'s': 72, 't': 29}, 'v': {'s': 71, 'u': 1, 't': 28}, 't': {'u': 71, 'v': 72}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第145轮
# 当前的流: {'s': {'u': 72, 'v': 72}, 'u': {'v': 0, 't': 72}, 'v': {'t': 72}, 't': {}}
# 残存网络: {'s': {'u': 28, 'v': 28}, 'u': {'s': 72, 'v': 1, 't': 28}, 'v': {'s': 72, 't': 28}, 't': {'u': 72, 'v': 72}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第146轮
# 当前的流: {'s': {'u': 73, 'v': 72}, 'u': {'v': 1, 't': 72}, 'v': {'t': 73}, 't': {}}
# 残存网络: {'s': {'u': 27, 'v': 28}, 'u': {'s': 73, 't': 28}, 'v': {'s': 72, 'u': 1, 't': 27}, 't': {'u': 72, 'v': 73}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第147轮
# 当前的流: {'s': {'u': 73, 'v': 73}, 'u': {'v': 0, 't': 73}, 'v': {'t': 73}, 't': {}}
# 残存网络: {'s': {'u': 27, 'v': 27}, 'u': {'s': 73, 'v': 1, 't': 27}, 'v': {'s': 73, 't': 27}, 't': {'u': 73, 'v': 73}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第148轮
# 当前的流: {'s': {'u': 74, 'v': 73}, 'u': {'v': 1, 't': 73}, 'v': {'t': 74}, 't': {}}
# 残存网络: {'s': {'u': 26, 'v': 27}, 'u': {'s': 74, 't': 27}, 'v': {'s': 73, 'u': 1, 't': 26}, 't': {'u': 73, 'v': 74}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第149轮
# 当前的流: {'s': {'u': 74, 'v': 74}, 'u': {'v': 0, 't': 74}, 'v': {'t': 74}, 't': {}}
# 残存网络: {'s': {'u': 26, 'v': 26}, 'u': {'s': 74, 'v': 1, 't': 26}, 'v': {'s': 74, 't': 26}, 't': {'u': 74, 'v': 74}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第150轮
# 当前的流: {'s': {'u': 75, 'v': 74}, 'u': {'v': 1, 't': 74}, 'v': {'t': 75}, 't': {}}
# 残存网络: {'s': {'u': 25, 'v': 26}, 'u': {'s': 75, 't': 26}, 'v': {'s': 74, 'u': 1, 't': 25}, 't': {'u': 74, 'v': 75}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第151轮
# 当前的流: {'s': {'u': 75, 'v': 75}, 'u': {'v': 0, 't': 75}, 'v': {'t': 75}, 't': {}}
# 残存网络: {'s': {'u': 25, 'v': 25}, 'u': {'s': 75, 'v': 1, 't': 25}, 'v': {'s': 75, 't': 25}, 't': {'u': 75, 'v': 75}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第152轮
# 当前的流: {'s': {'u': 76, 'v': 75}, 'u': {'v': 1, 't': 75}, 'v': {'t': 76}, 't': {}}
# 残存网络: {'s': {'u': 24, 'v': 25}, 'u': {'s': 76, 't': 25}, 'v': {'s': 75, 'u': 1, 't': 24}, 't': {'u': 75, 'v': 76}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第153轮
# 当前的流: {'s': {'u': 76, 'v': 76}, 'u': {'v': 0, 't': 76}, 'v': {'t': 76}, 't': {}}
# 残存网络: {'s': {'u': 24, 'v': 24}, 'u': {'s': 76, 'v': 1, 't': 24}, 'v': {'s': 76, 't': 24}, 't': {'u': 76, 'v': 76}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第154轮
# 当前的流: {'s': {'u': 77, 'v': 76}, 'u': {'v': 1, 't': 76}, 'v': {'t': 77}, 't': {}}
# 残存网络: {'s': {'u': 23, 'v': 24}, 'u': {'s': 77, 't': 24}, 'v': {'s': 76, 'u': 1, 't': 23}, 't': {'u': 76, 'v': 77}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第155轮
# 当前的流: {'s': {'u': 77, 'v': 77}, 'u': {'v': 0, 't': 77}, 'v': {'t': 77}, 't': {}}
# 残存网络: {'s': {'u': 23, 'v': 23}, 'u': {'s': 77, 'v': 1, 't': 23}, 'v': {'s': 77, 't': 23}, 't': {'u': 77, 'v': 77}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第156轮
# 当前的流: {'s': {'u': 78, 'v': 77}, 'u': {'v': 1, 't': 77}, 'v': {'t': 78}, 't': {}}
# 残存网络: {'s': {'u': 22, 'v': 23}, 'u': {'s': 78, 't': 23}, 'v': {'s': 77, 'u': 1, 't': 22}, 't': {'u': 77, 'v': 78}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第157轮
# 当前的流: {'s': {'u': 78, 'v': 78}, 'u': {'v': 0, 't': 78}, 'v': {'t': 78}, 't': {}}
# 残存网络: {'s': {'u': 22, 'v': 22}, 'u': {'s': 78, 'v': 1, 't': 22}, 'v': {'s': 78, 't': 22}, 't': {'u': 78, 'v': 78}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第158轮
# 当前的流: {'s': {'u': 79, 'v': 78}, 'u': {'v': 1, 't': 78}, 'v': {'t': 79}, 't': {}}
# 残存网络: {'s': {'u': 21, 'v': 22}, 'u': {'s': 79, 't': 22}, 'v': {'s': 78, 'u': 1, 't': 21}, 't': {'u': 78, 'v': 79}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第159轮
# 当前的流: {'s': {'u': 79, 'v': 79}, 'u': {'v': 0, 't': 79}, 'v': {'t': 79}, 't': {}}
# 残存网络: {'s': {'u': 21, 'v': 21}, 'u': {'s': 79, 'v': 1, 't': 21}, 'v': {'s': 79, 't': 21}, 't': {'u': 79, 'v': 79}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第160轮
# 当前的流: {'s': {'u': 80, 'v': 79}, 'u': {'v': 1, 't': 79}, 'v': {'t': 80}, 't': {}}
# 残存网络: {'s': {'u': 20, 'v': 21}, 'u': {'s': 80, 't': 21}, 'v': {'s': 79, 'u': 1, 't': 20}, 't': {'u': 79, 'v': 80}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第161轮
# 当前的流: {'s': {'u': 80, 'v': 80}, 'u': {'v': 0, 't': 80}, 'v': {'t': 80}, 't': {}}
# 残存网络: {'s': {'u': 20, 'v': 20}, 'u': {'s': 80, 'v': 1, 't': 20}, 'v': {'s': 80, 't': 20}, 't': {'u': 80, 'v': 80}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第162轮
# 当前的流: {'s': {'u': 81, 'v': 80}, 'u': {'v': 1, 't': 80}, 'v': {'t': 81}, 't': {}}
# 残存网络: {'s': {'u': 19, 'v': 20}, 'u': {'s': 81, 't': 20}, 'v': {'s': 80, 'u': 1, 't': 19}, 't': {'u': 80, 'v': 81}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第163轮
# 当前的流: {'s': {'u': 81, 'v': 81}, 'u': {'v': 0, 't': 81}, 'v': {'t': 81}, 't': {}}
# 残存网络: {'s': {'u': 19, 'v': 19}, 'u': {'s': 81, 'v': 1, 't': 19}, 'v': {'s': 81, 't': 19}, 't': {'u': 81, 'v': 81}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第164轮
# 当前的流: {'s': {'u': 82, 'v': 81}, 'u': {'v': 1, 't': 81}, 'v': {'t': 82}, 't': {}}
# 残存网络: {'s': {'u': 18, 'v': 19}, 'u': {'s': 82, 't': 19}, 'v': {'s': 81, 'u': 1, 't': 18}, 't': {'u': 81, 'v': 82}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第165轮
# 当前的流: {'s': {'u': 82, 'v': 82}, 'u': {'v': 0, 't': 82}, 'v': {'t': 82}, 't': {}}
# 残存网络: {'s': {'u': 18, 'v': 18}, 'u': {'s': 82, 'v': 1, 't': 18}, 'v': {'s': 82, 't': 18}, 't': {'u': 82, 'v': 82}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第166轮
# 当前的流: {'s': {'u': 83, 'v': 82}, 'u': {'v': 1, 't': 82}, 'v': {'t': 83}, 't': {}}
# 残存网络: {'s': {'u': 17, 'v': 18}, 'u': {'s': 83, 't': 18}, 'v': {'s': 82, 'u': 1, 't': 17}, 't': {'u': 82, 'v': 83}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第167轮
# 当前的流: {'s': {'u': 83, 'v': 83}, 'u': {'v': 0, 't': 83}, 'v': {'t': 83}, 't': {}}
# 残存网络: {'s': {'u': 17, 'v': 17}, 'u': {'s': 83, 'v': 1, 't': 17}, 'v': {'s': 83, 't': 17}, 't': {'u': 83, 'v': 83}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第168轮
# 当前的流: {'s': {'u': 84, 'v': 83}, 'u': {'v': 1, 't': 83}, 'v': {'t': 84}, 't': {}}
# 残存网络: {'s': {'u': 16, 'v': 17}, 'u': {'s': 84, 't': 17}, 'v': {'s': 83, 'u': 1, 't': 16}, 't': {'u': 83, 'v': 84}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第169轮
# 当前的流: {'s': {'u': 84, 'v': 84}, 'u': {'v': 0, 't': 84}, 'v': {'t': 84}, 't': {}}
# 残存网络: {'s': {'u': 16, 'v': 16}, 'u': {'s': 84, 'v': 1, 't': 16}, 'v': {'s': 84, 't': 16}, 't': {'u': 84, 'v': 84}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第170轮
# 当前的流: {'s': {'u': 85, 'v': 84}, 'u': {'v': 1, 't': 84}, 'v': {'t': 85}, 't': {}}
# 残存网络: {'s': {'u': 15, 'v': 16}, 'u': {'s': 85, 't': 16}, 'v': {'s': 84, 'u': 1, 't': 15}, 't': {'u': 84, 'v': 85}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第171轮
# 当前的流: {'s': {'u': 85, 'v': 85}, 'u': {'v': 0, 't': 85}, 'v': {'t': 85}, 't': {}}
# 残存网络: {'s': {'u': 15, 'v': 15}, 'u': {'s': 85, 'v': 1, 't': 15}, 'v': {'s': 85, 't': 15}, 't': {'u': 85, 'v': 85}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第172轮
# 当前的流: {'s': {'u': 86, 'v': 85}, 'u': {'v': 1, 't': 85}, 'v': {'t': 86}, 't': {}}
# 残存网络: {'s': {'u': 14, 'v': 15}, 'u': {'s': 86, 't': 15}, 'v': {'s': 85, 'u': 1, 't': 14}, 't': {'u': 85, 'v': 86}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第173轮
# 当前的流: {'s': {'u': 86, 'v': 86}, 'u': {'v': 0, 't': 86}, 'v': {'t': 86}, 't': {}}
# 残存网络: {'s': {'u': 14, 'v': 14}, 'u': {'s': 86, 'v': 1, 't': 14}, 'v': {'s': 86, 't': 14}, 't': {'u': 86, 'v': 86}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第174轮
# 当前的流: {'s': {'u': 87, 'v': 86}, 'u': {'v': 1, 't': 86}, 'v': {'t': 87}, 't': {}}
# 残存网络: {'s': {'u': 13, 'v': 14}, 'u': {'s': 87, 't': 14}, 'v': {'s': 86, 'u': 1, 't': 13}, 't': {'u': 86, 'v': 87}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第175轮
# 当前的流: {'s': {'u': 87, 'v': 87}, 'u': {'v': 0, 't': 87}, 'v': {'t': 87}, 't': {}}
# 残存网络: {'s': {'u': 13, 'v': 13}, 'u': {'s': 87, 'v': 1, 't': 13}, 'v': {'s': 87, 't': 13}, 't': {'u': 87, 'v': 87}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第176轮
# 当前的流: {'s': {'u': 88, 'v': 87}, 'u': {'v': 1, 't': 87}, 'v': {'t': 88}, 't': {}}
# 残存网络: {'s': {'u': 12, 'v': 13}, 'u': {'s': 88, 't': 13}, 'v': {'s': 87, 'u': 1, 't': 12}, 't': {'u': 87, 'v': 88}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第177轮
# 当前的流: {'s': {'u': 88, 'v': 88}, 'u': {'v': 0, 't': 88}, 'v': {'t': 88}, 't': {}}
# 残存网络: {'s': {'u': 12, 'v': 12}, 'u': {'s': 88, 'v': 1, 't': 12}, 'v': {'s': 88, 't': 12}, 't': {'u': 88, 'v': 88}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第178轮
# 当前的流: {'s': {'u': 89, 'v': 88}, 'u': {'v': 1, 't': 88}, 'v': {'t': 89}, 't': {}}
# 残存网络: {'s': {'u': 11, 'v': 12}, 'u': {'s': 89, 't': 12}, 'v': {'s': 88, 'u': 1, 't': 11}, 't': {'u': 88, 'v': 89}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第179轮
# 当前的流: {'s': {'u': 89, 'v': 89}, 'u': {'v': 0, 't': 89}, 'v': {'t': 89}, 't': {}}
# 残存网络: {'s': {'u': 11, 'v': 11}, 'u': {'s': 89, 'v': 1, 't': 11}, 'v': {'s': 89, 't': 11}, 't': {'u': 89, 'v': 89}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第180轮
# 当前的流: {'s': {'u': 90, 'v': 89}, 'u': {'v': 1, 't': 89}, 'v': {'t': 90}, 't': {}}
# 残存网络: {'s': {'u': 10, 'v': 11}, 'u': {'s': 90, 't': 11}, 'v': {'s': 89, 'u': 1, 't': 10}, 't': {'u': 89, 'v': 90}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第181轮
# 当前的流: {'s': {'u': 90, 'v': 90}, 'u': {'v': 0, 't': 90}, 'v': {'t': 90}, 't': {}}
# 残存网络: {'s': {'u': 10, 'v': 10}, 'u': {'s': 90, 'v': 1, 't': 10}, 'v': {'s': 90, 't': 10}, 't': {'u': 90, 'v': 90}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第182轮
# 当前的流: {'s': {'u': 91, 'v': 90}, 'u': {'v': 1, 't': 90}, 'v': {'t': 91}, 't': {}}
# 残存网络: {'s': {'u': 9, 'v': 10}, 'u': {'s': 91, 't': 10}, 'v': {'s': 90, 'u': 1, 't': 9}, 't': {'u': 90, 'v': 91}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第183轮
# 当前的流: {'s': {'u': 91, 'v': 91}, 'u': {'v': 0, 't': 91}, 'v': {'t': 91}, 't': {}}
# 残存网络: {'s': {'u': 9, 'v': 9}, 'u': {'s': 91, 'v': 1, 't': 9}, 'v': {'s': 91, 't': 9}, 't': {'u': 91, 'v': 91}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第184轮
# 当前的流: {'s': {'u': 92, 'v': 91}, 'u': {'v': 1, 't': 91}, 'v': {'t': 92}, 't': {}}
# 残存网络: {'s': {'u': 8, 'v': 9}, 'u': {'s': 92, 't': 9}, 'v': {'s': 91, 'u': 1, 't': 8}, 't': {'u': 91, 'v': 92}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第185轮
# 当前的流: {'s': {'u': 92, 'v': 92}, 'u': {'v': 0, 't': 92}, 'v': {'t': 92}, 't': {}}
# 残存网络: {'s': {'u': 8, 'v': 8}, 'u': {'s': 92, 'v': 1, 't': 8}, 'v': {'s': 92, 't': 8}, 't': {'u': 92, 'v': 92}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第186轮
# 当前的流: {'s': {'u': 93, 'v': 92}, 'u': {'v': 1, 't': 92}, 'v': {'t': 93}, 't': {}}
# 残存网络: {'s': {'u': 7, 'v': 8}, 'u': {'s': 93, 't': 8}, 'v': {'s': 92, 'u': 1, 't': 7}, 't': {'u': 92, 'v': 93}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第187轮
# 当前的流: {'s': {'u': 93, 'v': 93}, 'u': {'v': 0, 't': 93}, 'v': {'t': 93}, 't': {}}
# 残存网络: {'s': {'u': 7, 'v': 7}, 'u': {'s': 93, 'v': 1, 't': 7}, 'v': {'s': 93, 't': 7}, 't': {'u': 93, 'v': 93}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第188轮
# 当前的流: {'s': {'u': 94, 'v': 93}, 'u': {'v': 1, 't': 93}, 'v': {'t': 94}, 't': {}}
# 残存网络: {'s': {'u': 6, 'v': 7}, 'u': {'s': 94, 't': 7}, 'v': {'s': 93, 'u': 1, 't': 6}, 't': {'u': 93, 'v': 94}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第189轮
# 当前的流: {'s': {'u': 94, 'v': 94}, 'u': {'v': 0, 't': 94}, 'v': {'t': 94}, 't': {}}
# 残存网络: {'s': {'u': 6, 'v': 6}, 'u': {'s': 94, 'v': 1, 't': 6}, 'v': {'s': 94, 't': 6}, 't': {'u': 94, 'v': 94}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第190轮
# 当前的流: {'s': {'u': 95, 'v': 94}, 'u': {'v': 1, 't': 94}, 'v': {'t': 95}, 't': {}}
# 残存网络: {'s': {'u': 5, 'v': 6}, 'u': {'s': 95, 't': 6}, 'v': {'s': 94, 'u': 1, 't': 5}, 't': {'u': 94, 'v': 95}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第191轮
# 当前的流: {'s': {'u': 95, 'v': 95}, 'u': {'v': 0, 't': 95}, 'v': {'t': 95}, 't': {}}
# 残存网络: {'s': {'u': 5, 'v': 5}, 'u': {'s': 95, 'v': 1, 't': 5}, 'v': {'s': 95, 't': 5}, 't': {'u': 95, 'v': 95}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第192轮
# 当前的流: {'s': {'u': 96, 'v': 95}, 'u': {'v': 1, 't': 95}, 'v': {'t': 96}, 't': {}}
# 残存网络: {'s': {'u': 4, 'v': 5}, 'u': {'s': 96, 't': 5}, 'v': {'s': 95, 'u': 1, 't': 4}, 't': {'u': 95, 'v': 96}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第193轮
# 当前的流: {'s': {'u': 96, 'v': 96}, 'u': {'v': 0, 't': 96}, 'v': {'t': 96}, 't': {}}
# 残存网络: {'s': {'u': 4, 'v': 4}, 'u': {'s': 96, 'v': 1, 't': 4}, 'v': {'s': 96, 't': 4}, 't': {'u': 96, 'v': 96}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第194轮
# 当前的流: {'s': {'u': 97, 'v': 96}, 'u': {'v': 1, 't': 96}, 'v': {'t': 97}, 't': {}}
# 残存网络: {'s': {'u': 3, 'v': 4}, 'u': {'s': 97, 't': 4}, 'v': {'s': 96, 'u': 1, 't': 3}, 't': {'u': 96, 'v': 97}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第195轮
# 当前的流: {'s': {'u': 97, 'v': 97}, 'u': {'v': 0, 't': 97}, 'v': {'t': 97}, 't': {}}
# 残存网络: {'s': {'u': 3, 'v': 3}, 'u': {'s': 97, 'v': 1, 't': 3}, 'v': {'s': 97, 't': 3}, 't': {'u': 97, 'v': 97}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第196轮
# 当前的流: {'s': {'u': 98, 'v': 97}, 'u': {'v': 1, 't': 97}, 'v': {'t': 98}, 't': {}}
# 残存网络: {'s': {'u': 2, 'v': 3}, 'u': {'s': 98, 't': 3}, 'v': {'s': 97, 'u': 1, 't': 2}, 't': {'u': 97, 'v': 98}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第197轮
# 当前的流: {'s': {'u': 98, 'v': 98}, 'u': {'v': 0, 't': 98}, 'v': {'t': 98}, 't': {}}
# 残存网络: {'s': {'u': 2, 'v': 2}, 'u': {'s': 98, 'v': 1, 't': 2}, 'v': {'s': 98, 't': 2}, 't': {'u': 98, 'v': 98}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第198轮
# 当前的流: {'s': {'u': 99, 'v': 98}, 'u': {'v': 1, 't': 98}, 'v': {'t': 99}, 't': {}}
# 残存网络: {'s': {'u': 1, 'v': 2}, 'u': {'s': 99, 't': 2}, 'v': {'s': 98, 'u': 1, 't': 1}, 't': {'u': 98, 'v': 99}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第199轮
# 当前的流: {'s': {'u': 99, 'v': 99}, 'u': {'v': 0, 't': 99}, 'v': {'t': 99}, 't': {}}
# 残存网络: {'s': {'u': 1, 'v': 1}, 'u': {'s': 99, 'v': 1, 't': 1}, 'v': {'s': 99, 't': 1}, 't': {'u': 99, 'v': 99}}
# 增广路径: [('s', 'u'), ('u', 'v'), ('v', 't')]
# 残存容量: 1
# 第200轮
# 当前的流: {'s': {'u': 100, 'v': 99}, 'u': {'v': 1, 't': 99}, 'v': {'t': 100}, 't': {}}
# 残存网络: {'s': {'v': 1}, 'u': {'s': 100, 't': 1}, 'v': {'s': 99, 'u': 1}, 't': {'u': 99, 'v': 100}}
# 增广路径: [('s', 'v'), ('v', 'u'), ('u', 't')]
# 残存容量: 1
# 第201轮
# 当前的流: {'s': {'u': 100, 'v': 100}, 'u': {'v': 0, 't': 100}, 'v': {'t': 100}, 't': {}}
# 残存网络: {'s': {}, 'u': {'s': 100, 'v': 1}, 'v': {'s': 100}, 't': {'u': 100, 'v': 100}}
# 最大流值为200

# %%
c = {                               # #         s
    "s": {"a": 1, "b": 1, "d": 1},  # #      ╱|  ╲
    "a": {"t": 1},                  # #   ╱  |     ╲
    "b": {"a": 1, "c": 1},          # # a -- b -- c -- d
    "c": {"t": 1},                  # #   ╲     /  ╱
    "d": {"c": 1, "t": 1},          # #     ╲ / ╱
    "t": {}                         # #       t
}
ford_fulkerson(c, mode=3)
# Out:
# 第1轮
# 当前的流: {'s': {'a': 0, 'b': 0, 'd': 0}, 'a': {'t': 0}, 'b': {'a': 0, 'c': 0}, 'c': {'t': 0}, 'd': {'c': 0, 't': 0}, 't': {}}
# 残存网络: {'s': {'a': 1, 'b': 1, 'd': 1}, 'a': {'t': 1}, 'b': {'a': 1, 'c': 1}, 'c': {'t': 1}, 'd': {'c': 1, 't': 1}, 't': {}}
# 增广路径: [('s', 'a'), ('a', 't')]
# 残存容量: 1
# 第2轮
# 当前的流: {'s': {'a': 1, 'b': 0, 'd': 0}, 'a': {'t': 1}, 'b': {'a': 0, 'c': 0}, 'c': {'t': 0}, 'd': {'c': 0, 't': 0}, 't': {}}
# 残存网络: {'s': {'b': 1, 'd': 1}, 'a': {'s': 1}, 'b': {'a': 1, 'c': 1}, 'c': {'t': 1}, 'd': {'c': 1, 't': 1}, 't': {'a': 1}}
# 增广路径: [('s', 'd'), ('d', 't')]
# 残存容量: 1
# 第3轮
# 当前的流: {'s': {'a': 1, 'b': 0, 'd': 1}, 'a': {'t': 1}, 'b': {'a': 0, 'c': 0}, 'c': {'t': 0}, 'd': {'c': 0, 't': 1}, 't': {}}
# 残存网络: {'s': {'b': 1}, 'a': {'s': 1}, 'b': {'a': 1, 'c': 1}, 'c': {'t': 1}, 'd': {'s': 1, 'c': 1}, 't': {'a': 1, 'd': 1}}
# 增广路径: [('s', 'b'), ('b', 'c'), ('c', 't')]
# 残存容量: 1
# 第4轮
# 当前的流: {'s': {'a': 1, 'b': 1, 'd': 1}, 'a': {'t': 1}, 'b': {'a': 0, 'c': 1}, 'c': {'t': 1}, 'd': {'c': 0, 't': 1}, 't': {}}
# 残存网络: {'s': {}, 'a': {'s': 1}, 'b': {'s': 1, 'a': 1}, 'c': {'b': 1}, 'd': {'s': 1, 'c': 1}, 't': {'a': 1, 'c': 1, 'd': 1}}
# 最大流值为3
